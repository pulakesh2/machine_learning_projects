# %%
import pandas as pd

df:pd.DataFrame = pd.read_csv('data.csv')

df.head()
# Out:
#   Employee_ID              Job_Title    Industry Country Education_Level  \
# 0  AIJ-100000          Data Engineer  Healthcare   Japan             PhD
# 1  AIJ-100001     Healthcare Analyst      Retail      UK        Bachelor
# 2  AIJ-100002          HR Specialist   Education  Canada     High School
# 3  AIJ-100003  Cybersecurity Analyst  Government      UK        Bachelor
# 4  AIJ-100004     Healthcare Analyst   Education     UAE             PhD
#
#    Years_Experience  AI_Replacement_Risk  Future_Demand_Score  \
# 0                 1                 0.25                 0.78
# 1                24                 0.73                 0.33
# 2                21                 0.80                 0.69
# 3                 5                 0.29                 0.94
# 4                20                 0.11                 0.92
#
#   Remote_Work_Possibility  Average_Salary_USD  \
# 0                     Yes              207392
# 1                      No              140785
# ...

# %% [markdown]
# see data feature

# %%
print(df.shape)
print(df.info())
print(df.columns)
# Out:
# (3000, 20)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Employee_ID              3000 non-null   object
#  1   Job_Title                3000 non-null   object
#  2   Industry                 3000 non-null   object
#  3   Country                  3000 non-null   object
#  4   Education_Level          3000 non-null   object
#  5   Years_Experience         3000 non-null   int64
#  6   AI_Replacement_Risk      3000 non-null   float64
#  7   Future_Demand_Score      3000 non-null   float64
#  8   Remote_Work_Possibility  3000 non-null   object
#  9   Average_Salary_USD       3000 non-null   int64
#  10  Required_Skills          3000 non-null   object
#  11  Automation_Level         3000 non-null   object
#  12  Job_Growth_2030          3000 non-null   int64
# ...

# %% [markdown]
# check missing values

# %%
df.isnull().sum()
# Out:
# Employee_ID                0
# Job_Title                  0
# Industry                   0
# Country                    0
# Education_Level            0
# Years_Experience           0
# AI_Replacement_Risk        0
# Future_Demand_Score        0
# Remote_Work_Possibility    0
# Average_Salary_USD         0
# Required_Skills            0
# Automation_Level           0
# Job_Growth_2030            0
# Work_Hours_Per_Week        0
# Company_Size               0
# AI_Tool_Usage              0
# Performance_Score          0
# Upskilling_Needed          0
# Job_Satisfaction           0
# Hiring_Trend_2026          0
# dtype: int64

# %%
df.head()
# Out:
# 0            Data Engineer
# 1       Healthcare Analyst
# 2            HR Specialist
# 3    Cybersecurity Analyst
# 4       Healthcare Analyst
# Name: Job_Title, dtype: object

# %% [markdown]
# job v/s ai

# %%
job_ai_replaced = df.groupby('Job_Title')['AI_Replacement_Risk'].mean().sort_values(ascending=False)
job_ai_replaced
# Out:
# Job_Title
# DevOps Engineer              0.569013
# Cloud Architect              0.563876
# IoT Specialist               0.526667
# Prompt Engineer              0.522237
# Teacher                      0.520458
# Healthcare Analyst           0.518231
# Data Engineer                0.516954
# Cybersecurity Analyst        0.510185
# Robotics Engineer            0.506728
# Blockchain Developer         0.505677
# Software Developer           0.496951
# HR Specialist                0.492209
# Digital Marketer             0.489403
# Product Manager              0.486433
# Financial Analyst            0.485315
# AI Engineer                  0.476452
# Business Analyst             0.473475
# Machine Learning Engineer    0.472229
# Data Scientist               0.470263
# UX Designer                  0.460443
# Name: AI_Replacement_Risk, dtype: float64

# %% [markdown]
# which country devops get fire more

# %%
df_dev_ops = df[df['Job_Title'] == 'DevOps Engineer']

country_fire_dev_ops = df_dev_ops.groupby('Country')['AI_Replacement_Risk'].mean().sort_values(ascending=False)
country_fire_dev_ops
# Out:
# Country
# Germany      0.654444
# USA          0.610000
# Japan        0.585789
# Australia    0.576667
# India        0.575294
# Pakistan     0.564706
# Canada       0.556667
# UK           0.523750
# UAE          0.515000
# Singapore    0.473333
# Name: AI_Replacement_Risk, dtype: float64

# %% [markdown]
# which industry layoff more DevOps Engineer

# %%
layoff_industry_under_devops = df_dev_ops.groupby('Industry')['AI_Replacement_Risk'].mean().sort_values(ascending=False) 

layoff_industry_under_devops
# Out:
# Industry
# Government        0.722000
# Media             0.626667
# Finance           0.593333
# Education         0.569286
# Transportation    0.560769
# Manufacturing     0.558000
# Energy            0.556087
# Technology        0.541250
# Healthcare        0.525294
# Retail            0.427500
# Name: AI_Replacement_Risk, dtype: float64

# %% [markdown]
# industry v/s ai

# %%
industry_ai_replaced = df.groupby('Industry')['AI_Replacement_Risk'].mean().sort_values(ascending=False)

industry_ai_replaced
# Out:
# Industry
# Finance           0.530484
# Government        0.528793
# Technology        0.517423
# Energy            0.499164
# Education         0.496933
# Retail            0.496316
# Manufacturing     0.495875
# Transportation    0.493754
# Media             0.489547
# Healthcare        0.475238
# Name: AI_Replacement_Risk, dtype: float64

# %% [markdown]
# which country get fire more employees on finance

# %%
df_finance:pd.DataFrame = df[df['Industry'] == 'Finance']

country_fire_finance:pd.DataFrame = df_finance.groupby('Country')['AI_Replacement_Risk'].mean().sort_values(ascending=False)
country_fire_finance
# Out:
# Country
# UAE          0.591429
# USA          0.555556
# Pakistan     0.555455
# UK           0.552258
# Singapore    0.543846
# Australia    0.536500
# Canada       0.512800
# Germany      0.506486
# India        0.472692
# Japan        0.454118
# Name: AI_Replacement_Risk, dtype: float64

# %% [markdown]
# which role got high ai replace risk in Finance

# %%
high_risk_role_under_finance = df_finance.groupby('Job_Title')['AI_Replacement_Risk'].mean().sort_values(ascending=False)

high_risk_role_under_finance
# Out:
# Job_Title
# Digital Marketer             0.671111
# Product Manager              0.623636
# IoT Specialist               0.621818
# Financial Analyst            0.604000
# DevOps Engineer              0.593333
# Data Engineer                0.577647
# Teacher                      0.570667
# HR Specialist                0.543077
# Blockchain Developer         0.539091
# Healthcare Analyst           0.538000
# Software Developer           0.530625
# Prompt Engineer              0.528125
# Business Analyst             0.527143
# Cybersecurity Analyst        0.510000
# Data Scientist               0.507826
# Robotics Engineer            0.506471
# UX Designer                  0.505882
# Cloud Architect              0.438182
# Machine Learning Engineer    0.398125
# AI Engineer                  0.372000
# Name: AI_Replacement_Risk, dtype: float64

# %% [markdown]
# job, industry v/s ai

# %%
job_industry_replaced_by_ai = df.groupby(['Job_Title','Industry'])['AI_Replacement_Risk'].mean().sort_values(ascending=False)
job_industry_replaced_by_ai
# Out:
# Job_Title             Industry
# DevOps Engineer       Government        0.722000
# Cloud Architect       Education         0.712308
#                       Government        0.697500
# Digital Marketer      Finance           0.671111
# Blockchain Developer  Healthcare        0.641667
#                                           ...
# HR Specialist         Transportation    0.360000
# UX Designer           Healthcare        0.358750
# Data Scientist        Media             0.357778
# UX Designer           Media             0.328500
# Data Engineer         Education         0.320909
# Name: AI_Replacement_Risk, Length: 200, dtype: float64

# %% [markdown]
# future demand jobs

# %%
fututre_demand_job_report:pd.DataFrame = df.groupby('Job_Title')['Future_Demand_Score'].mean().sort_values(ascending=False)

fututre_demand_job_report
# Out:
# Job_Title
# Software Developer           0.627378
# Product Manager              0.622229
# Data Scientist               0.621711
# Business Analyst             0.620142
# Cybersecurity Analyst        0.616667
# IoT Specialist               0.614167
# Prompt Engineer              0.608355
# Healthcare Analyst           0.603878
# Teacher                      0.602876
# Machine Learning Engineer    0.602420
# Blockchain Developer         0.601032
# Financial Analyst            0.597273
# Digital Marketer             0.596045
# AI Engineer                  0.592177
# Robotics Engineer            0.591975
# Data Engineer                0.591788
# HR Specialist                0.585092
# UX Designer                  0.579051
# DevOps Engineer              0.574803
# Cloud Architect              0.568450
# Name: Future_Demand_Score, dtype: float64

# %% [markdown]
# which field has highest future demand for Software Developer

# %%
df_software_developer = df[df['Job_Title'] == 'Software Developer']

best_field_for_software_developer:pd.DataFrame = df_software_developer.groupby('Industry')['Future_Demand_Score'].mean().sort_values(ascending=False)

best_field_for_software_developer
# Out:
# Industry
# Government        0.696154
# Manufacturing     0.675000
# Education         0.664545
# Healthcare        0.658333
# Energy            0.653684
# Technology        0.638500
# Finance           0.611875
# Media             0.605238
# Transportation    0.552667
# Retail            0.490833
# Name: Future_Demand_Score, dtype: float64

# %% [markdown]
# which country has more demand for software developer

# %%
country_demand_software = df_software_developer.groupby('Country')['Future_Demand_Score'].mean().sort_values(ascending=False)
country_demand_software
# Out:
# Country
# Singapore    0.711111
# USA          0.683125
# Japan        0.669444
# India        0.665714
# Germany      0.639444
# Australia    0.635000
# UAE          0.595789
# Canada       0.578333
# Pakistan     0.541333
# UK           0.541111
# Name: Future_Demand_Score, dtype: float64

# %% [markdown]
# future market industry

# %%
future_industry_report:pd.DataFrame = df.groupby('Industry')['Future_Demand_Score'].mean().sort_values(ascending=False)
future_industry_report
# Out:
# Industry
# Government        0.621115
# Healthcare        0.612930
# Finance           0.610710
# Manufacturing     0.605314
# Education         0.598833
# Retail            0.597544
# Energy            0.595642
# Technology        0.593471
# Media             0.589721
# Transportation    0.585290
# Name: Future_Demand_Score, dtype: float64

# %% [markdown]
# future demand job under government

# %%
df_government:pd.DataFrame = df[df['Industry'] == 'Government']

future_demand_job_under_gov:pd.DataFrame = df_government.groupby('Job_Title')['Future_Demand_Score'].mean().sort_values(ascending=False)
future_demand_job_under_gov
# Out:
# Job_Title
# AI Engineer                  0.716154
# Data Engineer                0.703478
# Software Developer           0.696154
# Data Scientist               0.686818
# Financial Analyst            0.675000
# Cloud Architect              0.655000
# Prompt Engineer              0.649091
# Robotics Engineer            0.642083
# UX Designer                  0.627000
# Teacher                      0.610909
# Business Analyst             0.596000
# Cybersecurity Analyst        0.591875
# Digital Marketer             0.590000
# Product Manager              0.580000
# Blockchain Developer         0.570909
# Machine Learning Engineer    0.557333
# DevOps Engineer              0.555333
# HR Specialist                0.554167
# Healthcare Analyst           0.540769
# IoT Specialist               0.531250
# Name: Future_Demand_Score, dtype: float64

# %% [markdown]
# demand country for goverment

# %%
country_demand_government = df_government.groupby('Country')['Future_Demand_Score'].mean().sort_values(ascending=False)
country_demand_government
# Out:
# Country
# Japan        0.681111
# UAE          0.673824
# Singapore    0.624074
# India        0.620769
# USA          0.620571
# Canada       0.612889
# Australia    0.609459
# Germany      0.607838
# Pakistan     0.585455
# UK           0.575909
# Name: Future_Demand_Score, dtype: float64

# %% [markdown]
# future market role industry

# %%
future_market_role_report:pd.DataFrame = df.groupby(['Job_Title','Industry'])['Future_Demand_Score'].mean().sort_values(ascending=False)

future_market_role_report
# Out:
# Job_Title              Industry
# Business Analyst       Technology        0.767500
# Cybersecurity Analyst  Retail            0.749231
#                        Healthcare        0.736316
# Financial Analyst      Healthcare        0.735455
# IoT Specialist         Technology        0.716364
#                                            ...
# Software Developer     Retail            0.490833
# Data Engineer          Technology        0.488824
# Cloud Architect        Transportation    0.479231
# Teacher                Education         0.479091
# Cloud Architect        Technology        0.475000
# Name: Future_Demand_Score, Length: 200, dtype: float64

# %% [markdown]
# future demand v/s ai risk

# %%
import matplotlib.pyplot as plt

plt.scatter(df['Future_Demand_Score'], df['AI_Replacement_Risk'])
plt.xlabel('Future_Demand_Score')
plt.ylabel('AI_Replacement_Risk')
plt.title('Future demand v/s Ai risk')
plt.show()

# %% [markdown]
# which country has ai replacement high

# %%
df_country = df.groupby('Country')['AI_Replacement_Risk'].mean().sort_values(ascending=False)

df_country
# Out:
# Country
# Pakistan     0.526367
# Japan        0.511773
# UAE          0.506455
# Germany      0.505346
# Canada       0.501684
# Australia    0.500769
# USA          0.497390
# UK           0.495570
# India        0.495520
# Singapore    0.484944
# Name: AI_Replacement_Risk, dtype: float64

# %% [markdown]
# which job is more risk in ai in pakistan

# %%
df_pakistan = df[df['Country'] == 'Pakistan'].sort_values('AI_Replacement_Risk', ascending=False)


df_pakistan_job_title = df_pakistan.groupby('Job_Title')['AI_Replacement_Risk'].mean().sort_values(ascending=False)
df_pakistan_job_title

# df_pakistan
# Out:
# Job_Title
# Cloud Architect              0.671429
# Prompt Engineer              0.634667
# Financial Analyst            0.630000
# Blockchain Developer         0.615000
# Data Engineer                0.591176
# Cybersecurity Analyst        0.581667
# DevOps Engineer              0.564706
# Product Manager              0.536000
# Digital Marketer             0.535455
# Healthcare Analyst           0.532000
# IoT Specialist               0.526667
# UX Designer                  0.524615
# Machine Learning Engineer    0.523636
# Robotics Engineer            0.507500
# Data Scientist               0.484583
# Software Developer           0.482667
# HR Specialist                0.455000
# Business Analyst             0.443684
# Teacher                      0.440000
# AI Engineer                  0.435000
# Name: AI_Replacement_Risk, dtype: float64

# %% [markdown]
# which field in pakistand is more ai risky

# %%
df_industry_ai_impact = df_pakistan.groupby('Industry')['AI_Replacement_Risk'].mean().sort_values(ascending=False)
df_industry_ai_impact
# Out:
# Industry
# Transportation    0.584815
# Technology        0.571818
# Finance           0.555455
# Education         0.544615
# Energy            0.543889
# Retail            0.525161
# Healthcare        0.523333
# Government        0.508788
# Manufacturing     0.477000
# Media             0.442069
# Name: AI_Replacement_Risk, dtype: float64

# %% [markdown]
# which has max ai impact in pakistan

# %%
df_pakistan.head(3)
# Out:
#      Employee_ID              Job_Title       Industry   Country  \
# 2352  AIJ-102352  Cybersecurity Analyst  Manufacturing  Pakistan
# 256   AIJ-100256          HR Specialist        Finance  Pakistan
# 2527  AIJ-102527        Prompt Engineer     Government  Pakistan
#
#      Education_Level  Years_Experience  AI_Replacement_Risk  \
# 2352        Bachelor                 5                 0.95
# 256      High School                17                 0.95
# 2527     High School                16                 0.94
#
#       Future_Demand_Score Remote_Work_Possibility  Average_Salary_USD  \
# 2352                 0.58                     Yes               55135
# 256                  0.97                  Hybrid               68050
# 2527                 0.54                      No               41694
#
#                                         Required_Skills Automation_Level  \
# 2352  Communication, Leadership, Kubernetes, Machine...             High
# ...

# %% [markdown]
# pakistan future demand

# %%
df_pakistan_future_job_demand = df_pakistan.groupby('Job_Title')['Future_Demand_Score'].mean().sort_values(ascending=False)

df_pakistan_future_job_demand
# Out:
# Job_Title
# Financial Analyst            0.707778
# Product Manager              0.683000
# Cloud Architect              0.682857
# DevOps Engineer              0.680588
# HR Specialist                0.626667
# Teacher                      0.626000
# Cybersecurity Analyst        0.624444
# Healthcare Analyst           0.624000
# Prompt Engineer              0.622000
# Machine Learning Engineer    0.610000
# IoT Specialist               0.601333
# Data Scientist               0.600000
# Digital Marketer             0.597273
# UX Designer                  0.588462
# Data Engineer                0.587059
# Robotics Engineer            0.551875
# Software Developer           0.541333
# Business Analyst             0.508947
# AI Engineer                  0.495455
# Blockchain Developer         0.462500
# Name: Future_Demand_Score, dtype: float64

# %% [markdown]
# in financial analyst, which industry is more demanding in pakistan

# %%
df_pakistan_financial = df_pakistan[df_pakistan['Job_Title'] == 'Financial Analyst']
df_pakistan_financial.groupby('Industry')['Future_Demand_Score'].mean().sort_values(ascending=False)
# Out:
# Industry
# Government        0.950
# Technology        0.840
# Media             0.830
# Transportation    0.780
# Energy            0.700
# Retail            0.500
# Finance           0.495
# Name: Future_Demand_Score, dtype: float64

# %% [markdown]
# which industry has high demand

# %%
df_pakistan_high_demand_industry = df_pakistan.groupby('Industry')['Future_Demand_Score'].mean().sort_values(ascending=False)
df_pakistan_high_demand_industry
# Out:
# Industry
# Healthcare        0.687576
# Technology        0.675000
# Manufacturing     0.609667
# Energy            0.607500
# Government        0.585455
# Finance           0.583939
# Education         0.565000
# Retail            0.559032
# Transportation    0.555556
# Media             0.528621
# Name: Future_Demand_Score, dtype: float64

# %% [markdown]
# in healthcare industry of pakistan, which role is more demanding

# %%
df_pakistan_healthcare_industry = df_pakistan[df_pakistan['Industry'] == 'Healthcare']

df_pakistan_healthcare_industry.groupby('Job_Title')['Future_Demand_Score'].mean().sort_values(ascending=False)
# Out:
# Job_Title
# Data Engineer                0.940000
# DevOps Engineer              0.856667
# Cybersecurity Analyst        0.836667
# HR Specialist                0.800000
# Digital Marketer             0.780000
# Business Analyst             0.750000
# Healthcare Analyst           0.730000
# Data Scientist               0.685000
# Cloud Architect              0.656667
# IoT Specialist               0.620000
# Prompt Engineer              0.603333
# Machine Learning Engineer    0.600000
# AI Engineer                  0.575000
# Software Developer           0.565000
# Blockchain Developer         0.360000
# UX Designer                  0.270000
# Name: Future_Demand_Score, dtype: float64

# %% [markdown]
# top countries which has ai replacement high

# %%
df_sort_by_ai = df.sort_values('AI_Replacement_Risk', ascending=False)

df_sort_by_ai.head()
# Out:
#      Employee_ID          Job_Title        Industry    Country  \
# 1272  AIJ-101272    DevOps Engineer      Government    Germany
# 2279  AIJ-102279  Robotics Engineer  Transportation  Australia
# 916   AIJ-100916     IoT Specialist         Finance        USA
# 1925  AIJ-101925    DevOps Engineer      Government      India
# 2889  AIJ-102889    Prompt Engineer           Media    Germany
#
#      Education_Level  Years_Experience  AI_Replacement_Risk  \
# 1272     High School                20                 0.95
# 2279        Bachelor                22                 0.95
# 916      High School                 5                 0.95
# 1925             PhD                 0                 0.95
# 2889             PhD                23                 0.95
#
#       Future_Demand_Score Remote_Work_Possibility  Average_Salary_USD  \
# 1272                 0.33                  Hybrid               79553
# 2279                 0.36                  Hybrid              196688
# ...

# %% [markdown]
# # india analysis

# %%
df_india = df[df['Country'] == 'India'].sort_values('AI_Replacement_Risk', ascending=False)

df_india.head(2)
# Out:
#      Employee_ID              Job_Title    Industry Country Education_Level  \
# 295   AIJ-100295  Cybersecurity Analyst       Media   India             PhD
# 1925  AIJ-101925        DevOps Engineer  Government   India             PhD
#
#       Years_Experience  AI_Replacement_Risk  Future_Demand_Score  \
# 295                 17                 0.95                 0.39
# 1925                 0                 0.95                 0.28
#
#      Remote_Work_Possibility  Average_Salary_USD  \
# 295                       No              131913
# 1925                     Yes              213934
#
#                                         Required_Skills Automation_Level  \
# 295   Prompt Engineering, Cybersecurity, SQL, Cloud ...              Low
# 1925  Data Visualization, Cloud Computing, Deep Lear...             High
#
#       Job_Growth_2030  Work_Hours_Per_Week Company_Size AI_Tool_Usage  \
# 295                -8                   40      Startup      Moderate
# ...

# %% [markdown]
# which job is afected more by ai overall in all field

# %%
df_india.groupby('Job_Title')['AI_Replacement_Risk'].mean().sort_values(ascending=False)
# Out:
# Job_Title
# Data Engineer                0.672308
# Cloud Architect              0.590000
# DevOps Engineer              0.575294
# Healthcare Analyst           0.562632
# Data Scientist               0.558667
# Machine Learning Engineer    0.545385
# Robotics Engineer            0.525714
# Prompt Engineer              0.517000
# IoT Specialist               0.511538
# Digital Marketer             0.495000
# Teacher                      0.477273
# Blockchain Developer         0.473846
# HR Specialist                0.467500
# Cybersecurity Analyst        0.461000
# AI Engineer                  0.452000
# Financial Analyst            0.450714
# UX Designer                  0.437778
# Software Developer           0.413571
# Business Analyst             0.408750
# Product Manager              0.361429
# Name: AI_Replacement_Risk, dtype: float64

# %% [markdown]
# if data engineer job is afected by overall then which field get high ai risk in overall

# %%
df_india[df_india['Job_Title'] == 'Data Engineer'].groupby('Industry')['AI_Replacement_Risk'].mean().sort_values(ascending=False)
# Out:
# Industry
# Government       0.860000
# Healthcare       0.735000
# Finance          0.633333
# Manufacturing    0.620000
# Technology       0.613333
# Education        0.330000
# Name: AI_Replacement_Risk, dtype: float64

# %% [markdown]
# in india, which industry is more affected by ai

# %%
df_india.groupby('Industry')['AI_Replacement_Risk'].mean().sort_values(ascending=False)
# Out:
# Industry
# Transportation    0.555600
# Government        0.537692
# Media             0.517391
# Manufacturing     0.510385
# Retail            0.509231
# Technology        0.489118
# Education         0.480606
# Finance           0.472692
# Healthcare        0.466400
# Energy            0.443714
# Name: AI_Replacement_Risk, dtype: float64

# %% [markdown]
# in transportation, which job role is affected more

# %%
df_india[df_india['Industry']== 'Transportation'].groupby('Job_Title')['AI_Replacement_Risk'].mean().sort_values(ascending=False)
# Out:
# Job_Title
# Machine Learning Engineer    0.890000
# Blockchain Developer         0.870000
# Digital Marketer             0.810000
# DevOps Engineer              0.800000
# Healthcare Analyst           0.696667
# Business Analyst             0.563333
# IoT Specialist               0.532500
# Product Manager              0.495000
# Robotics Engineer            0.480000
# UX Designer                  0.400000
# HR Specialist                0.370000
# Financial Analyst            0.333333
# Cybersecurity Analyst        0.130000
# Name: AI_Replacement_Risk, dtype: float64

# %% [markdown]
# # now the future demand of india

# %% [markdown]
# best specific deman jobs in india

# %%
df_india_demand = df_india.sort_values('Future_Demand_Score', ascending=False)
df_india_demand.head()
# Out:
#      Employee_ID           Job_Title       Industry Country Education_Level  \
# 2751  AIJ-102751   Robotics Engineer        Finance   India             PhD
# 2944  AIJ-102944      Data Scientist     Government   India     High School
# 2927  AIJ-102927    Digital Marketer         Energy   India        Bachelor
# 2738  AIJ-102738    Digital Marketer         Energy   India             PhD
# 312   AIJ-100312  Software Developer  Manufacturing   India             PhD
#
#       Years_Experience  AI_Replacement_Risk  Future_Demand_Score  \
# 2751                14                 0.08                 0.99
# 2944                 2                 0.37                 0.99
# 2927                11                 0.83                 0.98
# 2738                 7                 0.15                 0.98
# 312                  5                 0.49                 0.97
#
#      Remote_Work_Possibility  Average_Salary_USD  \
# 2751                      No               99753
# ...

# %% [markdown]
# in which job, demand is high

# %%
df_india_demand.groupby('Job_Title')['Future_Demand_Score'].mean().sort_values(ascending=False)
# Out:
# Job_Title
# Product Manager              0.681429
# Software Developer           0.665714
# Cybersecurity Analyst        0.654500
# IoT Specialist               0.650000
# Prompt Engineer              0.645000
# Robotics Engineer            0.642857
# UX Designer                  0.633889
# Blockchain Developer         0.632308
# Data Scientist               0.610667
# Business Analyst             0.600000
# HR Specialist                0.596667
# Healthcare Analyst           0.581053
# Machine Learning Engineer    0.578462
# Digital Marketer             0.576875
# AI Engineer                  0.572000
# Financial Analyst            0.563571
# DevOps Engineer              0.534118
# Teacher                      0.511818
# Cloud Architect              0.501429
# Data Engineer                0.480769
# Name: Future_Demand_Score, dtype: float64

# %% [markdown]
# in product manager, which field has high demand of this role

# %%
df_india_demand[df_india_demand['Job_Title'] == 'Product Manager'].groupby('Industry')['Future_Demand_Score'].mean().sort_values(ascending=False)
# Out:
# Industry
# Healthcare        0.923333
# Education         0.793333
# Media             0.680000
# Transportation    0.605000
# Energy            0.526667
# Technology        0.240000
# Name: Future_Demand_Score, dtype: float64

# %% [markdown]
# in which field, demand is high overall

# %%
df_india_demand.groupby('Industry')['Future_Demand_Score'].mean().sort_values(ascending=False)
# Out:
# Industry
# Healthcare        0.652400
# Energy            0.647714
# Manufacturing     0.628846
# Government        0.620769
# Education         0.615455
# Media             0.599565
# Finance           0.585769
# Transportation    0.578000
# Retail            0.548077
# Technology        0.522647
# Name: Future_Demand_Score, dtype: float64

# %% [markdown]
# in healthcare, which role has high demand

# %%
df_india_demand[df_india_demand['Industry'] == 'Healthcare'].groupby('Job_Title')['Future_Demand_Score'].mean().sort_values(ascending=False)
# Out:
# Job_Title
# Product Manager              0.923333
# Cybersecurity Analyst        0.910000
# Teacher                      0.910000
# UX Designer                  0.835000
# Prompt Engineer              0.705000
# Healthcare Analyst           0.695000
# Business Analyst             0.680000
# AI Engineer                  0.670000
# Robotics Engineer            0.670000
# Data Engineer                0.590000
# Software Developer           0.545000
# Machine Learning Engineer    0.510000
# DevOps Engineer              0.475000
# Blockchain Developer         0.420000
# Financial Analyst            0.320000
# HR Specialist                0.250000
# Name: Future_Demand_Score, dtype: float64

# %% [markdown]
# which has high ai risk-> remote or office work

# %%
df.groupby('Remote_Work_Possibility')['AI_Replacement_Risk'].mean().sort_values(ascending=False)
# Out:
# Remote_Work_Possibility
# Hybrid    0.510425
# Yes       0.502074
# No        0.496055
# Name: AI_Replacement_Risk, dtype: float64

# %% [markdown]
# which job has high satisfaction

# %%
df.groupby('Job_Title')['Job_Satisfaction'].mean().sort_values(ascending=False)
# Out:
# Job_Title
# Digital Marketer             3.296119
# Data Scientist               3.233553
# IoT Specialist               3.128125
# UX Designer                  3.114937
# Blockchain Developer         3.093677
# Financial Analyst            3.060699
# AI Engineer                  3.052097
# Software Developer           3.048415
# Prompt Engineer              3.040132
# Cloud Architect              3.036822
# Cybersecurity Analyst        3.024691
# Data Engineer                3.015099
# DevOps Engineer              3.000592
# Robotics Engineer            2.963210
# Product Manager              2.942994
# HR Specialist                2.941718
# Business Analyst             2.928723
# Healthcare Analyst           2.917891
# Teacher                      2.867712
# Machine Learning Engineer    2.864076
# Name: Job_Satisfaction, dtype: float64

# %% [markdown]
# which job has high salary

# %%
df.groupby('Job_Title')['Average_Salary_USD'].mean().sort_values(ascending=False)
# Out:
# Job_Title
# HR Specialist                131881.742331
# Cloud Architect              131847.294574
# IoT Specialist               130848.791667
# Business Analyst             129792.574468
# Teacher                      129674.267974
# Data Engineer                129308.748344
# Product Manager              129052.350318
# Digital Marketer             128626.388060
# UX Designer                  126833.803797
# Data Scientist               126710.236842
# AI Engineer                  126480.806452
# Financial Analyst            125720.860140
# Healthcare Analyst           125543.775510
# Software Developer           124828.103659
# Prompt Engineer              124047.282895
# DevOps Engineer              123977.802632
# Robotics Engineer            123748.179012
# Cybersecurity Analyst        123691.197531
# Machine Learning Engineer    122658.458599
# Blockchain Developer         119250.212903
# Name: Average_Salary_USD, dtype: float64

# %% [markdown]
# job which need upskalling

# %%
upskilling_jobs = df[df['Upskilling_Needed'] == 'Yes']
upskilling_jobs['Job_Title']
# Out:
# 0                   Data Engineer
# 5       Machine Learning Engineer
# 6                     UX Designer
# 8               Robotics Engineer
# 10                Cloud Architect
#                   ...
# 2992              DevOps Engineer
# 2993               Data Scientist
# 2995               Data Scientist
# 2997              DevOps Engineer
# 2998               Data Scientist
# Name: Job_Title, Length: 1489, dtype: object

# %% [markdown]
# job which don't need upskilling

# %%
non_up_skilling_jobs = df[df['Upskilling_Needed'] == 'No']
non_up_skilling_jobs['Job_Title']
# Out:
# 1              Healthcare Analyst
# 2                   HR Specialist
# 3           Cybersecurity Analyst
# 4              Healthcare Analyst
# 7                Digital Marketer
#                   ...
# 2989                HR Specialist
# 2991    Machine Learning Engineer
# 2994              Prompt Engineer
# 2996                Data Engineer
# 2999                HR Specialist
# Name: Job_Title, Length: 1511, dtype: object

# %% [markdown]
# salary v/s satisfaction, upskaliing v/s ai tools used, remote work v/s satisfaction/salary, in india(salary v/s satisfaction, remote_work v/s satisfaction)

# %% [markdown]
# salary v/s satisfaction

# %%
df.head()


plt.scatter(df['Average_Salary_USD'],df['Job_Satisfaction'])
plt.title('salary v/s job satisfaction')
plt.xlabel('salary')
plt.ylabel('job satisfaction')
plt.show()

# %% [markdown]
# upskilling job v/s ai tools used

# %%
upskilling_jobs['AI_Tool_Usage'].value_counts()
# Out:
# AI_Tool_Usage
# Low         511
# High        508
# Moderate    470
# Name: count, dtype: int64

# %% [markdown]
# nonskilling job v/s ai tools used

# %%
non_up_skilling_jobs['AI_Tool_Usage'].value_counts()
# Out:
# AI_Tool_Usage
# Low         522
# High        506
# Moderate    483
# Name: count, dtype: int64

# %% [markdown]
# which job has long work hours per week

# %%
df_india.groupby('Job_Title')['Work_Hours_Per_Week'].mean().sort_values(ascending=False)
# Out:
# Job_Title
# Prompt Engineer              53.000000
# Product Manager              48.857143
# Healthcare Analyst           47.368421
# Cloud Architect              47.285714
# AI Engineer                  47.000000
# Cybersecurity Analyst        46.950000
# Financial Analyst            46.285714
# Data Scientist               46.200000
# Machine Learning Engineer    45.923077
# Business Analyst             45.562500
# Software Developer           44.857143
# Robotics Engineer            44.500000
# Data Engineer                44.461538
# Blockchain Developer         44.230769
# IoT Specialist               44.230769
# DevOps Engineer              42.588235
# UX Designer                  42.555556
# Teacher                      41.818182
# Digital Marketer             41.125000
# HR Specialist                41.000000
# Name: Work_Hours_Per_Week, dtype: float64

# %% [markdown]
# in which industry has high work hours per week

# %%
df_india.groupby('Industry')['Work_Hours_Per_Week'].mean().sort_values(ascending=False)
# Out:
# Industry
# Finance           47.153846
# Healthcare        46.280000
# Manufacturing     46.153846
# Education         45.848485
# Government        45.307692
# Transportation    45.160000
# Technology        44.529412
# Media             44.173913
# Energy            43.800000
# Retail            43.615385
# Name: Work_Hours_Per_Week, dtype: float64

# %% [markdown]
# all over india working hours

# %%
df.groupby('Job_Title')['Work_Hours_Per_Week'].mean().sort_values(ascending=False)
# Out:
# Job_Title
# Software Developer           45.823171
# Blockchain Developer         45.787097
# Machine Learning Engineer    45.433121
# Prompt Engineer              45.394737
# Cybersecurity Analyst        45.308642
# Product Manager              45.299363
# Financial Analyst            45.104895
# UX Designer                  44.873418
# Healthcare Analyst           44.802721
# Robotics Engineer            44.765432
# Cloud Architect              44.689922
# IoT Specialist               44.631944
# Data Scientist               44.486842
# Data Engineer                44.410596
# Business Analyst             44.347518
# AI Engineer                  44.346774
# Digital Marketer             44.231343
# HR Specialist                44.202454
# Teacher                      43.901961
# DevOps Engineer              43.315789
# Name: Work_Hours_Per_Week, dtype: float64

# %% [markdown]
# which industry in world work high

# %%
df.groupby('Industry')['Work_Hours_Per_Week'].mean().sort_values(ascending=False)
# Out:
# Industry
# Education         46.016667
# Technology        45.213058
# Media             45.181185
# Healthcare        45.153846
# Manufacturing     44.765677
# Transportation    44.587031
# Finance           44.509677
# Government        44.501548
# Retail            44.200000
# Energy            43.782090
# Name: Work_Hours_Per_Week, dtype: float64

# %% [markdown]
# remote work and office work v/s satisfaction in whole world

# %%
df_remote_work = df[df['Remote_Work_Possibility'] == 'Yes']
remote_work_satisfaction = df_remote_work['Job_Satisfaction'].sum()

df_office_work = df[df['Remote_Work_Possibility'] == 'No']
office_work_satisfaction = df_remote_work['Job_Satisfaction'].sum()

print(f"remote work satisfaction: {remote_work_satisfaction}")
print(f"office work satisfaction: {office_work_satisfaction}")
# Out:
# remote work satisfaction: 3.01814556331007
# office work satisfaction: 3.01814556331007

# %% [markdown]
# remote work and office work v/s satisfaction in india

# %%
df_remote_work = df_india[df_india['Remote_Work_Possibility'] == 'Yes']
remote_work_satisfaction = df_remote_work['Job_Satisfaction'].sum()

df_office_work = df_india[df_india['Remote_Work_Possibility'] == 'No']
office_work_satisfaction = df_remote_work['Job_Satisfaction'].sum()

print(f"remote work satisfaction: {remote_work_satisfaction}")
print(f"office work satisfaction: {office_work_satisfaction}")
# Out:
# remote work satisfaction: 343.35999999999996
# office work satisfaction: 343.35999999999996

# %% [markdown]
# satisfied job in india

# %%
df_india.groupby('Job_Title')['Job_Satisfaction'].mean().sort_values(ascending=False)
# Out:
# Job_Title
# Teacher                      3.644545
# UX Designer                  3.586667
# Digital Marketer             3.466250
# DevOps Engineer              3.427059
# Blockchain Developer         3.302308
# Cloud Architect              3.292857
# IoT Specialist               3.250769
# Financial Analyst            3.216429
# Machine Learning Engineer    3.210000
# Product Manager              3.200000
# AI Engineer                  3.177000
# Data Scientist               3.176667
# Prompt Engineer              3.096000
# Robotics Engineer            3.084286
# Software Developer           3.082857
# Cybersecurity Analyst        3.076500
# Data Engineer                2.884615
# HR Specialist                2.691667
# Business Analyst             2.608125
# Healthcare Analyst           2.415789
# Name: Job_Satisfaction, dtype: float64

# %% [markdown]
# best growing role

# %%
df[df['Hiring_Trend_2026'] == 'Growing'].groupby('Job_Title')['Future_Demand_Score'].mean().sort_values(ascending=False)
# Out:
# Job_Title
# Product Manager              0.664364
# Business Analyst             0.649773
# IoT Specialist               0.639310
# Healthcare Analyst           0.633529
# AI Engineer                  0.631875
# HR Specialist                0.616458
# Cybersecurity Analyst        0.614000
# Teacher                      0.612041
# Software Developer           0.603871
# Data Scientist               0.602917
# Prompt Engineer              0.600492
# Digital Marketer             0.598913
# Robotics Engineer            0.594000
# Financial Analyst            0.589756
# Machine Learning Engineer    0.588333
# Blockchain Developer         0.580192
# Data Engineer                0.573488
# DevOps Engineer              0.573208
# UX Designer                  0.562321
# Cloud Architect              0.549167
# Name: Future_Demand_Score, dtype: float64

# %% [markdown]
# in india best growing job role

# %%
df_india[df_india['Hiring_Trend_2026'] == 'Growing'].groupby('Job_Title')['Future_Demand_Score'].mean().sort_values(ascending=False)
# Out:
# Job_Title
# Product Manager              0.797500
# AI Engineer                  0.670000
# IoT Specialist               0.637500
# Prompt Engineer              0.628000
# Blockchain Developer         0.627500
# Cybersecurity Analyst        0.625714
# Healthcare Analyst           0.597500
# Digital Marketer             0.573333
# UX Designer                  0.571429
# Software Developer           0.570000
# Business Analyst             0.540000
# Robotics Engineer            0.538000
# Financial Analyst            0.532500
# HR Specialist                0.523333
# Machine Learning Engineer    0.472500
# DevOps Engineer              0.471429
# Data Scientist               0.455000
# Data Engineer                0.416667
# Teacher                      0.392500
# Cloud Architect              0.325000
# Name: Future_Demand_Score, dtype: float64
